# %% [markdown]
# ### Step 1: Import necessary libraries
#
# We start by importing the `pandas` library for data manipulation and `requests` for making HTTP requests to external APIs. NOTE: THIS CODE IS DIRECTLY GIVEN BY TMDB API AND print(response.text) IS JUST FOR SHOWING YOU THE DATA FOR PAGE-1.

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Step 2: Make an initial API request to fetch top-rated movies
#
# We define the API endpoint URL and the necessary authorization headers. Then, we use `requests.get()` to send the request and store the response. This initial call helps us understand the API response structure before looping through all pages.

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2MDk3MzcwZjE2MmE5YzIwY2NjYWJjODdiMTJmY2FlNCIsIm5iZiI6MTc3MTEzMTU5NS44MzgsInN1YiI6IjY5OTE1MmNiMWZhNmE3ZTdjYTk1OGE4NyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.5nBaJVfnMqpvKG6ikzsGNk7KhC9yYiOIo_gky6-c0vI"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg","genre_ids":[18,80],"id":278,"original_language":"en","original_title":"The Shawshank Redemption","overview":"Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.","popularity":30.8191,"poster_path":"/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg","release_date":"1994-09-23","title":"The Shawshank Redemption","video":false,"vote_average":8.716,"vote_count":29721},{"adult":false,"backdrop_path":"/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg","genre_ids":[18,80],"id":238,"original_language":"en","original_title":"The Godfather","overview":"Spanning the years 1945 to 1955, a chronicle of the fi
# ...

# %% [markdown]
# ### Step 3: Display the response object
#
# This shows the status of the HTTP request, confirming if it was successful (e.g., `<Response [200]>` indicates success).

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Step 4: Parse the API response into JSON
#
# We convert the raw HTTP response content into a Python dictionary or list using `.json()`, making the data accessible for processing.

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 30.8191,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.716,
#    'vote_count': 29721},
#   {'adult': False,
#    'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#    'genre_ids': [18, 80],
# ...

# %% [markdown]
# ### Step 5: Extract the 'results' key from the JSON response
#
# The actual movie data is typically nested under a 'results' key in the API response. We extract this list of movie dictionaries.

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 30.8191,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.716,
#   'vote_count': 29721},
#  {'adult': False,
#   'backdrop_path': '/tSPT36ZKlP2WVHJLM4cQPLSzv3b.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %% [markdown]
# ### Step 6: Display the temporary DataFrame
#
# This step allows us to preview the structure and content of the DataFrame created from a single page's API response.

# %%
temp_df = pd.DataFrame(response.json()['results'])

# %% [markdown]
# ### Step 7: Re-create a temporary DataFrame with a different set of selected columns
#
# This adjusts the columns selected from the API response for better data representation in the DataFrame.

# %%
temp_df = pd.DataFrame(response.json()['results'])[['genre_ids','id','original_language','overview','popularity','release_date','title','vote_average','vote_count']]

# %%
temp_df
# Out:
#           genre_ids      id original_language  \
# 0          [18, 80]     278                en
# 1          [18, 80]     238                en
# 2          [18, 80]     240                en
# 3   [18, 36, 10752]     424                en
# 4              [18]     389                en
# 5   [16, 10751, 14]     129                ja
# 6      [28, 80, 53]     155                en
# 7   [35, 18, 10749]   19404                hi
# 8      [14, 18, 80]     497                en
# 9      [35, 53, 18]  496243                ko
# 10     [12, 14, 28]     122                en
# 11     [53, 80, 35]     680                en
# 12  [16, 10749, 18]  372058                ja
# 13             [37]     429                it
# 14    [12, 18, 878]  157336                en
# 15  [35, 18, 10749]      13                en
# 16         [18, 80]     769                en
# 17         [28, 18]     346                ja
# 18  [16, 18, 10752]   12477                ja
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Step 8: Loop through API pages to collect all movie data
#
# This loop iterates from page 1 up to the maximum valid page (500 in this case, based on the API's limitation). For each page, it makes an API request, parses the JSON response, extracts movie data, and appends it to our main DataFrame (`df`). It also includes error handling for cases where the 'results' key might be missing (e.g., when an invalid page number is requested).
#
# IT WAS GIVING ERROR ON RESULTS AS PAGES AFTER 500 DIDN'T CONTAIN RESULTS

# %%
for i in range (1,553):
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)
    headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI2MDk3MzcwZjE2MmE5YzIwY2NjYWJjODdiMTJmY2FlNCIsIm5iZiI6MTc3MTEzMTU5NS44MzgsInN1YiI6IjY5OTE1MmNiMWZhNmE3ZTdjYTk1OGE4NyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.5nBaJVfnMqpvKG6ikzsGNk7KhC9yYiOIo_gky6-c0vI"
    }
    response = requests.get(url, headers=headers)
    response_json = response.json()
    if 'results' in response_json:
        temp_df = pd.DataFrame(response_json['results'])[['genre_ids','id','original_language','overview','popularity','release_date','title','vote_average','vote_count']]
        df = pd.concat([df, temp_df], ignore_index=True)
    else:
        print(f"Warning: 'results' key not found in response for page {i}. Response content: {response_json}")
        # Optionally, you can break the loop or handle this case differently
        break # Breaking the loop as an example, you might want to continue or log this.

# %%
df
# Out:
#                 genre_ids      id original_language  \
# 0                [18, 80]     278                en
# 1                [18, 80]     238                en
# 2                [18, 80]     240                en
# 3         [18, 36, 10752]     424                en
# 4                    [18]     389                en
# ...                   ...     ...               ...
# 9995             [27, 35]   10012                en
# 9996         [28, 53, 80]  480042                en
# 9997           [27, 9648]  465086                en
# 9998             [35, 53]  276839                en
# 9999  [12, 10751, 35, 14]   39346                en
#
#                                                overview  popularity  \
# 0     Imprisoned in the 1940s for the double murder ...     30.8191
# 1     Spanning the years 1945 to 1955, a chronicle o...     36.4215
# 2     In the continuing saga of the Corleone crime f...     17.5941
# ...

# %% [markdown]
# ### Step 9: Display the shape of the final DataFrame
#
# This shows the number of rows (movies) and columns (attributes) in our comprehensive dataset, confirming how much data was successfully collected.

# %%
df.shape
# Out:
# (10000, 9)

# %%
df.to_csv('movies.csv')
